# %% [markdown]
# # Environment

# %%
# %matplotlib inline
from sci_analysis import analyze
import numpy as np
import ddfloww as dd

# %% [markdown]
# # Acquire Data

# %%
df = dd.get_zillow()

# %% [markdown]
# # Analyze!

# %%
analyze(df.logerror)
# Out:
# /usr/local/anaconda3/lib/python3.7/site-packages/scipy/stats/morestats.py:1309: UserWarning: p-value may not be accurate for N > 5000.
#   warnings.warn("p-value may not be accurate for N > 5000.")
# Statistics
# ----------
#
# n         =  167888
# Mean      =  0.0139
# Std Dev   =  0.1657
# Std Error =  0.0004
# Skewness  =  2.9508
# Kurtosis  =  121.3859
# Maximum   =  5.2630
# 75%       =  0.0392
# 50%       =  0.0060
# 25%       = -0.0253
# Minimum   = -4.6554
# IQR       =  0.0645
# Range     =  9.9184
#
#
# Shapiro-Wilk test for normality
# -------------------------------
#
# alpha   =  0.0500
# W value =  0.5131
# p value =  0.0000
#
# HA: Data is not normally distributed

# %%
analyze(df.logerror, df.calculatedfinishedsquarefeet)
# Out:
# Linear Regression
# -----------------
#
# n         =  166992
# Slope     =  226.8437
# Intercept =  1775.4699
# r         =  0.0397
# r^2       =  0.0016
# Std Err   =  13.9680
# p value   =  0.0000
#
#
#
# Spearman Correlation Coefficient
# --------------------------------
#
# alpha   =  0.0500
# r value =  0.0735
# p value =  0.0000
#
# HA: There is a significant relationship between predictor and response
# /usr/local/anaconda3/lib/python3.7/site-packages/scipy/stats/morestats.py:1309: UserWarning: p-value may not be accurate for N > 5000.
#   warnings.warn("p-value may not be accurate for N > 5000.")
# /usr/local/anaconda3/lib/python3.7/site-packages/scipy/stats/morestats.py:1309: UserWarning: p-value may not be accurate for N > 5000.
#   warnings.warn("p-value may not be accurate for N > 5000.")

# %%
analyze(df.taxamount, df.landtaxvaluedollarcnt)
# Out:
# Linear Regression
# -----------------
#
# n         =  167840
# Slope     =  57.0612
# Intercept = -52897.4885
# r         =  0.9238
# r^2       =  0.8534
# Std Err   =  0.0577
# p value   =  0.0000
#
#
#
# Spearman Correlation Coefficient
# --------------------------------
#
# alpha   =  0.0500
# r value =  0.8727
# p value =  0.0000
#
# HA: There is a significant relationship between predictor and response
# /usr/local/anaconda3/lib/python3.7/site-packages/scipy/stats/morestats.py:1309: UserWarning: p-value may not be accurate for N > 5000.
#   warnings.warn("p-value may not be accurate for N > 5000.")
# /usr/local/anaconda3/lib/python3.7/site-packages/scipy/stats/morestats.py:1309: UserWarning: p-value may not be accurate for N > 5000.
#   warnings.warn("p-value may not be accurate for N > 5000.")
