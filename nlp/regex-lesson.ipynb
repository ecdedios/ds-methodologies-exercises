# %% [markdown]
# # Environment

# %%
import ddfloww as dd
import pandas as pd
import re

from pydataset import data

# %%
tips = data('tips')

# %%
dd.select(tips, 'sex', 'smoker', total_bill='total', size='party_size')
# Out:
#         sex smoker  total  party_size
# 1    Female     No  16.99           2
# 2      Male     No  10.34           3
# 3      Male     No  21.01           3
# 4      Male     No  23.68           2
# 5    Female     No  24.59           4
# 6      Male     No  25.29           4
# 7      Male     No   8.77           2
# 8      Male     No  26.88           4
# 9      Male     No  15.04           2
# 10     Male     No  14.78           2
# 11     Male     No  10.27           2
# 12   Female     No  35.26           4
# 13     Male     No  15.42           2
# 14     Male     No  18.43           4
# 15   Female     No  14.83           2
# 16     Male     No  21.58           2
# 17   Female     No  10.33           3
# 18     Male     No  16.29           3
# 19   Female     No  16.97           3
# 20     Male     No  20.65           3
# 21     Male     No  17.92           2
# 22   Female     No  20.29           2
# 23   Female     No  15.77           2
# 24     Male     No  39.42           4
# 25     Male     No  19.82           2
# 26     Male     No  17.81           4
# 27     Male     No  13.37           2
# 28     Male     No  12.69           2
# 29     Male     No  21.70           2
# 30   Female     No  19.65           2
# 31     Male     No   9.55           2
# 32     Male     No  18.35           4
# 33   Female     No  15.06           2
# 34   Female     No  20.69           4
# 35     Male     No  17.78           2
# 36     Male     No  24.06           3
# 37     Male     No  16.31           3
# 38   Female     No  16.93           3
# 39     Male     No  18.69           3
# 40     Male     No  31.27           3
# 41     Male     No  16.04           3
# 42     Male     No  17.46           2
# 43     Male     No  13.94           2
# 44     Male     No   9.68           2
# 45     Male     No  30.40           4
# 46     Male     No  18.29           2
# 47     Male     No  22.23           2
# 48     Male     No  32.40           4
# 49     Male     No  28.55           3
# 50     Male     No  18.04           2
# 51     Male     No  12.54           2
# 52   Female     No  10.29           2
# 53   Female     No  34.81           4
# 54     Male     No   9.94           2
# 55     Male     No  25.56           4
# 56     Male     No  19.49           2
# 57     Male    Yes  38.01           4
# 58   Female     No  26.41           2
# 59     Male    Yes  11.24           2
# 60     Male     No  48.27           4
# 61     Male    Yes  20.29           2
# 62     Male    Yes  13.81           2
# 63     Male    Yes  11.02           2
# 64     Male    Yes  18.29           4
# 65     Male     No  17.59           3
# 66     Male     No  20.08           3
# 67   Female     No  16.45           2
# 68   Female    Yes   3.07           1
# 69     Male     No  20.23           2
# 70     Male    Yes  15.01           2
# 71     Male     No  12.02           2
# 72   Female     No  17.07           3
# 73   Female    Yes  26.86           2
# 74   Female    Yes  25.28           2
# 75   Female     No  14.73           2
# 76     Male     No  10.51           2
# 77     Male    Yes  17.92           2
# 78     Male     No  27.20           4
# 79     Male     No  22.76           2
# 80     Male     No  17.29           2
# 81     Male    Yes  19.44           2
# 82     Male     No  16.66           2
# 83   Female     No  10.07           1
# 84     Male    Yes  32.68           2
# 85     Male     No  15.98           2
# ..      ...    ...    ...         ...
# 160    Male     No  16.49           4
# 161    Male     No  21.50           4
# 162    Male     No  12.66           2
# 163  Female     No  16.21           3
# 164    Male     No  13.81           2
# 165  Female    Yes  17.51           2
# 166    Male     No  24.52           3
# 167    Male     No  20.76           2
# 168    Male     No  31.71           4
# 169  Female    Yes  10.59           2
# 170  Female    Yes  10.63           2
# 171    Male    Yes  50.81           3
# 172    Male    Yes  15.81           2
# 173    Male    Yes   7.25           2
# 174    Male    Yes  31.85           2
# 175    Male    Yes  16.82           2
# 176    Male    Yes  32.90           2
# 177    Male    Yes  17.89           2
# 178    Male    Yes  14.48           2
# 179  Female    Yes   9.60           2
# 180    Male    Yes  34.63           2
# 181    Male    Yes  34.65           4
# 182    Male    Yes  23.33           2
# 183    Male    Yes  45.35           3
# 184    Male    Yes  23.17           4
# 185    Male    Yes  40.55           2
# 186    Male     No  20.69           5
# 187  Female    Yes  20.90           3
# 188    Male    Yes  30.46           5
# 189  Female    Yes  18.15           3
# 190    Male    Yes  23.10           3
# 191    Male    Yes  15.69           2
# 192  Female    Yes  19.81           2
# 193    Male    Yes  28.44           2
# 194    Male    Yes  15.48           2
# 195    Male    Yes  16.58           2
# 196    Male     No   7.56           2
# 197    Male    Yes  10.34           2
# 198  Female    Yes  43.11           4
# 199  Female    Yes  13.00           2
# 200    Male    Yes  13.51           2
# 201    Male    Yes  18.71           3
# 202  Female    Yes  12.74           2
# 203  Female    Yes  13.00           2
# 204  Female    Yes  16.40           2
# 205    Male    Yes  20.53           4
# 206  Female    Yes  16.47           3
# 207    Male    Yes  26.59           3
# 208    Male    Yes  38.73           4
# 209    Male    Yes  24.27           2
# 210  Female    Yes  12.76           2
# 211    Male    Yes  30.06           3
# 212    Male    Yes  25.89           4
# 213    Male     No  48.33           4
# 214  Female    Yes  13.27           2
# 215  Female    Yes  28.17           3
# 216  Female    Yes  12.90           2
# 217    Male    Yes  28.15           5
# 218    Male    Yes  11.59           2
# 219    Male    Yes   7.74           2
# 220  Female    Yes  30.14           4
# 221    Male    Yes  12.16           2
# 222  Female    Yes  13.42           2
# 223    Male    Yes   8.58           1
# 224  Female     No  15.98           3
# 225    Male    Yes  13.42           2
# 226  Female    Yes  16.27           2
# 227  Female    Yes  10.09           2
# 228    Male     No  20.45           4
# 229    Male     No  13.28           2
# 230  Female    Yes  22.12           2
# 231    Male    Yes  24.01           4
# 232    Male    Yes  15.69           3
# 233    Male     No  11.61           2
# 234    Male     No  10.77           2
# 235    Male    Yes  15.53           2
# 236    Male     No  10.07           2
# 237    Male    Yes  12.60           2
# 238    Male    Yes  32.83           2
# 239  Female     No  35.83           3
# 240    Male     No  29.03           3
# 241  Female    Yes  27.18           2
# 242    Male    Yes  22.67           2
# 243    Male     No  17.82           2
# 244  Female     No  18.78           2
#
# [244 rows x 4 columns]

# %%
re.findall(r'b', 'abcd')
# Out:
# ['b']

# %%
sentence = 'Mary had a little lamb. 1 little lamb. Not 10, not 12, not 22, just one.'
dd.show_all_matches([
    r'a',
    r'm',
    r'M',
    r'Mary',
    r'little',
    r'1',
    r'10',
    r'22'
], sentence)
# Out:
# Sentence:
#
#     Mary had a little lamb. 1 little lamb. Not 10, not 12, not 22, just one.
#
#  regexp | matches
#  ------ | -------
#  a      | ['a', 'a', 'a', 'a', 'a']
#  m      | ['m', 'm']
#  M      | ['M']
#  Mary   | ['Mary']
#  little | ['little', 'little']
#  1      | ['1', '1', '1']
#  10     | ['10']
#  22     | ['22']

# %%
res = [
    r'\w',
    r'\d',
    r'\s',
    r'.', # matches every character
    r'\.', # a literal period
]
dd.show_all_matches(res, sentence)
# Out:
# Sentence:
#
#     Mary had a little lamb. 1 little lamb. Not 10, not 12, not 22, just one.
#
#  regexp | matches
#  ------ | -------
#  \w     | ['M', 'a', 'r', 'y', 'h', 'a', 'd', 'a', '...']
#  \d     | ['1', '1', '0', '1', '2', '2', '2']
#  \s     | [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', '...']
#  .      | ['M', 'a', 'r', 'y', ' ', 'h', 'a', 'd', '...']
#  \.     | ['.', '.', '.']

# %%
dd.show_all_matches([r'l\w\w\w\W', r'\d\d'], sentence, re_length=9)
# Out:
# Sentence:
#
#     Mary had a little lamb. 1 little lamb. Not 10, not 12, not 22, just one.
#
#  regexp    | matches
#  ------    | -------
#  l\w\w\w\W | ['lamb.', 'lamb.']
#  \d\d      | ['10', '12', '22']

# %%
dd.show_all_matches([
    r'\d+'
], sentence)

print('\n---\n')

dd.show_all_matches([
    r'a{2,}',
    r'a{2}',
    r'a{3,4}'
], 'aabbaaaa')
# Out:
# Sentence:
#
#     Mary had a little lamb. 1 little lamb. Not 10, not 12, not 22, just one.
#
#  regexp | matches
#  ------ | -------
#  \d+    | ['1', '10', '12', '22']
#
# ---
#
# Sentence:
#
#     aabbaaaa
#
#  regexp | matches
#  ------ | -------
#  a{2,}  | ['aa', 'aaaa']
#  a{2}   | ['aa', 'aa', 'aa']
#  a{3,4} | ['aaaa']

# %%
dd.show_all_matches([
    r'[lt]',
    r'[lt]+',
    r'[^aeiou\s\.]', # any letter that's not a vowel
    r'[a-d]'
], sentence, re_length=12)
# Out:
# Sentence:
#
#     Mary had a little lamb. 1 little lamb. Not 10, not 12, not 22, just one.
#
#  regexp       | matches
#  ------       | -------
#  [lt]         | ['l', 't', 't', 'l', 'l', 'l', 't', 't', '...']
#  [lt]+        | ['l', 'ttl', 'l', 'l', 'ttl', 'l', 't', 't', '...']
#  [^aeiou\s\.] | ['M', 'r', 'y', 'h', 'd', 'l', 't', 't', '...']
#  [a-d]        | ['a', 'a', 'd', 'a', 'a', 'b', 'a', 'b']

# %%
dd.show_all_matches([
    r'\bo\w+', # any word that starts with an 'o'
    r'^\s', # starts with a space
    r'^M', # starts with 'M'
    r'\.$', # ends with a period
], sentence)
# Out:
# Sentence:
#
#     Mary had a little lamb. 1 little lamb. Not 10, not 12, not 22, just one.
#
#  regexp | matches
#  ------ | -------
#  \bo\w+ | ['one']
#  ^\s    | []
#  ^M     | ['M']
#  \.$    | ['.']

# %%
sentence = '''
You can find us on the web at https://codeup.com. Our ip address is 123.123.123.123 (maybe).
'''.strip()

# %%
ip_re = r'\d+(\.\d+){3}'

match = re.search(ip_re, sentence)
match[0]
# Out:
# '123.123.123.123'

# %%
url_re = r'(https?)://(\w+)\.(\w+)'

protocol, domain, tld = re.search(url_re, sentence).groups()

print(f'''
protocol: {protocol}
domain: {domain}
tld: {tld}
''')
# Out:
# protocol: https
# domain: codeup
# tld: com

# %%
# \w{4,5}://(\w+\.)+\w{2,}

# %% [markdown]
# # EXERCISES

# %% [markdown]
# ### 1. Write a function named `is_vowel`. It should accept a string input and use a regular expression to determine  if the passed string is a vowel. You can treat the result of `re.search` as a boolean value that indicates whether or not the regular expression matches the given string.

# %% [markdown]
# ### 2. Write a function named `is_valid_username` that accepts a string input. A valid username starts with a lowercase letter, and only consists of lowercase letters, numbers, or the _ character. It should also be no longer than 32 characters. The function should return either `True` or `False` depending on whether the passed string is a valid username.

# %% [markdown]
# ### 3. Write a regular expression to capture phone numbers. It should match all of the following:
#
#     (210) 867 5309
#     +1 210.867.5309
#     867-5309
#     210-867-5309

# %% [markdown]
# ### 4. Use regular expressions to convert the dates below to the standardized year-month-day format.
